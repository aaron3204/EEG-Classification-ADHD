# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mne
from sklearn.model_selection import KFold
from sklearn.metrics import (classification_report, roc_auc_score, 
                             confusion_matrix, roc_curve, auc)
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras import layers, models, utils, callbacks, regularizers
from mne.preprocessing import ICA
from scipy.stats import kurtosis
from scipy.signal import welch

plt.style.use('ggplot')
sns.set_palette("husl")


# Parameters

CSV_PATH = "adhdata.csv"
SFREQ = 128.0
EPOCH_LENGTH = 2.0
TEST_SIZE = 0.2
BATCH_SIZE = 32
EPOCHS = 100
DROP_RATE = 0.5
L2_REG = 1e-4


# Frequency bands for feature extraction

BANDS = {
    'delta': (1, 4),
    'theta': (4, 8),
    'alpha': (8, 13),
    'beta': (13, 30),
    'gamma': (30, 40)
}


# EEGNet Architecture

def EEGNet(nb_classes=2, Chans=19, Samples=256,
           dropoutRate=DROP_RATE, kernLength=64, F1=8, D=2, F2=16, l2=L2_REG):
    input1 = layers.Input((Chans, Samples, 1))
    
    x = layers.Conv2D(F1, (1, kernLength), padding='same', use_bias=False,
                      kernel_regularizer=regularizers.l2(l2))(input1)
    x = layers.BatchNormalization()(x)
    
    x = layers.DepthwiseConv2D((Chans, 1), use_bias=False, depth_multiplier=D,
                              depthwise_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.AveragePooling2D((1, 4))(x)
    x = layers.Dropout(dropoutRate)(x)
    
    x = layers.SeparableConv2D(F2, (1, 16), use_bias=False, padding='same',
                              depthwise_regularizer=regularizers.l2(l2),
                              pointwise_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.AveragePooling2D((1, 8))(x)
    x = layers.Dropout(dropoutRate)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(nb_classes, kernel_regularizer=regularizers.l2(l2))(x)
    output = layers.Activation('softmax')(x)
    
    return models.Model(inputs=input1, outputs=output)


# DeepConvNet Architecture

def DeepConvNet(nb_classes=2, Chans=19, Samples=256, dropoutRate=DROP_RATE, l2=L2_REG):
    input1 = layers.Input((Chans, Samples, 1))
    
    x = layers.Conv2D(25, (1, 5), kernel_regularizer=regularizers.l2(l2))(input1)
    x = layers.Conv2D(25, (Chans, 1), kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.MaxPooling2D((1, 2))(x)
    x = layers.Dropout(dropoutRate)(x)
    
    x = layers.Conv2D(50, (1, 5), kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.MaxPooling2D((1, 2))(x)
    x = layers.Dropout(dropoutRate)(x)
    
    x = layers.Conv2D(100, (1, 5), kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.MaxPooling2D((1, 2))(x)
    x = layers.Dropout(dropoutRate)(x)
    
    x = layers.Conv2D(200, (1, 5), kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('elu')(x)
    x = layers.MaxPooling2D((1, 2))(x)
    x = layers.Dropout(dropoutRate)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(nb_classes, kernel_regularizer=regularizers.l2(l2))(x)
    output = layers.Activation('softmax')(x)
    
    return models.Model(inputs=input1, outputs=output)


# Feature Extraction Function

def compute_band_powers(X, sfreq, bands):
    n_epochs, n_channels, n_times = X.shape
    f, psd = welch(X.reshape(n_epochs * n_channels, n_times), fs=sfreq, nperseg=128, axis=-1)
    psd = psd.reshape(n_epochs, n_channels, -1)
    
    band_powers = []
    for band_name, (low, high) in bands.items():
        idx_band = np.where((f >= low) & (f < high))[0]
        if len(idx_band) == 0:
            continue
        power = psd[:, :, idx_band].sum(axis=2)
        band_powers.append(power)
    
    band_powers = np.stack(band_powers, axis=2)
    band_powers = band_powers.reshape(n_epochs, -1)
    return band_powers


# Data Loading & Preprocessing

def load_and_preprocess():
    df = pd.read_csv(CSV_PATH)
    channels = df.columns[:19].tolist()
    
    X, y, groups = [], [], []
    for pid, group in df.groupby('ID'):
        try:
            data = group[channels].T.values * 1e-6
            info = mne.create_info(channels, sfreq=SFREQ, ch_types='eeg')
            raw = mne.io.RawArray(data, info)
            
            raw.set_eeg_reference('average')
            raw.filter(1, 40, fir_design='firwin')
            
            def implement_ica(raw):
                original_raw = raw.copy()
                ica = ICA(random_state=97, max_iter=800)
                ica.fit(raw)
                sources = ica.get_sources(raw).get_data()
                component_kurtosis = kurtosis(sources, axis=1)
                kurtosis_95th_percentile = np.percentile(component_kurtosis, 95)
                components_to_exclude = np.where(component_kurtosis >= kurtosis_95th_percentile)[0]
                ica.exclude = components_to_exclude
                try:
                    cleaned_raw = ica.apply(raw)
                    return cleaned_raw
                except:
                    return original_raw
            
            raw = implement_ica(raw)
            
            events = mne.make_fixed_length_events(raw, duration=EPOCH_LENGTH)
            epochs = mne.Epochs(raw, events, tmin=0, tmax=EPOCH_LENGTH,
                               baseline=None, preload=True)
            
            if len(epochs) == 0:
                print(f"No epochs created for patient {pid}")
                continue
                
            n_epochs = len(epochs)
            X.append(epochs.get_data())
            y.extend([group['Class'].iloc[0]] * n_epochs)
            groups.extend([pid] * n_epochs)
            
        except Exception as e:
            print(f"Error processing patient {pid}: {str(e)}")
            continue

    X = np.concatenate(X)
    y = LabelEncoder().fit_transform(y)
    return X, y, groups

X, y, groups = load_and_preprocess()
print(f"Data shape: {X.shape}")
print(f"Class distribution: {np.unique(y, return_counts=True)}")


# Visualization

def plot_metrics(history):
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    ax[0].plot(history.history['accuracy'], label='Train')
    ax[0].plot(history.history['val_accuracy'], label='Validation')
    ax[0].set_title('Accuracy')
    ax[0].legend()
    
    ax[1].plot(history.history['loss'], label='Train')
    ax[1].plot(history.history['val_loss'], label='Validation')
    ax[1].set_title('Loss')
    # plt.savefig(f'metrics_fold.png')
    # plt.close()
    plt.show()

def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    # plt.savefig('confusion_matrix.png')
    # plt.close()
    plt.show()

def plot_roc(y_true, y_probs, model_name):
    fpr, tpr, _ = roc_curve(y_true, y_probs)
    roc_auc = auc(fpr, tpr)
    
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, 
             label=f'ROC (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {model_name}')
    plt.legend(loc="lower right")
    # plt.savefig(f'roc_curve_{model_name}.png')
    # plt.close()
    plt.show()


# Model Training & Evaluation

def evaluate_models(X, y, groups):
    gkf = KFold(n_splits=5, shuffle=True, random_state=42)
    results = {'eegnet': [], 'deepconvnet': [], 'random_forest': [], 'svm': [], 'logistic_regression': []}
    
    for fold, (train_idx, test_idx) in enumerate(gkf.split(X, y)):
        print(f"\n{'='*40}\nFold {fold+1}\n{'='*40}")
        
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        

        # Deep Learning Processing

        scaler = StandardScaler()
        n_tr, n_ch, n_t = X_train.shape
        X_train = scaler.fit_transform(X_train.reshape(n_tr, -1)).reshape(n_tr, n_ch, n_t)
        X_test = scaler.transform(X_test.reshape(len(test_idx), -1)).reshape(len(test_idx), n_ch, n_t)
        
        X_train_eeg = X_train[..., np.newaxis]
        X_test_eeg = X_test[..., np.newaxis]
        y_train_cat = utils.to_categorical(y_train)
        

        # EEGNet Training

        print("\nTraining EEGNet...")
        eegnet_model = EEGNet(nb_classes=2, Chans=n_ch, Samples=n_t)
        eegnet_model.compile(optimizer='adam', 
                            loss='categorical_crossentropy', 
                            metrics=['accuracy'])
        
        history_eegnet = eegnet_model.fit(
            X_train_eeg, y_train_cat,
            validation_data=(X_test_eeg, utils.to_categorical(y_test)),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            callbacks=[
                callbacks.EarlyStopping(patience=10, restore_best_weights=True),
                callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
            ],
            verbose=1
        )
        
        y_probs_eegnet = eegnet_model.predict(X_test_eeg)[:, 1]
        results['eegnet'].append(roc_auc_score(y_test, y_probs_eegnet))
        plot_metrics(history_eegnet)
        

        # DeepConvNet Training

        print("\nTraining DeepConvNet...")
        deepconv_model = DeepConvNet(nb_classes=2, Chans=n_ch, Samples=n_t)
        deepconv_model.compile(optimizer='adam', 
                              loss='categorical_crossentropy', 
                              metrics=['accuracy'])
        
        history_deepconv = deepconv_model.fit(
            X_train_eeg, y_train_cat,
            validation_data=(X_test_eeg, utils.to_categorical(y_test)),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            callbacks=[
                callbacks.EarlyStopping(patience=10, restore_best_weights=True),
                callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
            ],
            verbose=1
        )
        
        y_probs_deepconv = deepconv_model.predict(X_test_eeg)[:, 1]
        results['deepconvnet'].append(roc_auc_score(y_test, y_probs_deepconv))
        plot_metrics(history_deepconv)
        

        # ML Model Processing

        ml_models = {
            'Random Forest': RandomForestClassifier(n_estimators=200),
            'SVM': make_pipeline(StandardScaler(), SVC(kernel='rbf', probability=True)),
            'Logistic Regression': make_pipeline(StandardScaler(), LogisticRegression())
        }
        
        X_train_ml = compute_band_powers(X_train, SFREQ, BANDS)
        X_test_ml = compute_band_powers(X_test, SFREQ, BANDS)
        
        for name, estimator in ml_models.items():
            print(f"\nTraining {name}...")
            estimator.fit(X_train_ml, y_train)
            y_pred = estimator.predict_proba(X_test_ml)[:, 1]
            key_name = name.lower().replace(' ', '_')
            results[key_name].append(roc_auc_score(y_test, y_pred))
        
        # Plot fold results

        plot_roc(y_test, y_probs_eegnet, 'EEGNet')
        plot_roc(y_test, y_probs_deepconv, 'DeepConvNet')
        plt.figure(figsize=(10,6))
        pd.DataFrame(results).plot(kind='box')
        plt.title('Model Comparison - Current Fold')
        plt.ylabel('ROC AUC')
        # plt.savefig(f'model_comparison_fold_{fold+1}.png')
        # plt.close()
        plt.show()
    
    # Final results

    print("\nFinal Results:")
    for model, scores in results.items():
        print(f"{model.upper():<20} Mean ROC-AUC: {np.mean(scores):.3f} ± {np.std(scores):.3f}")
    
    return results

results = evaluate_models(X, y, groups)
# Out:
# 2025-05-01 18:07:19.237200: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-01 18:07:19.384849: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746103039.438123    5832 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746103039.453993    5832 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746103039.572712    5832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746103039.572743    5832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746103039.572744    5832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746103039.572746    5832 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-01 18:07:19.587247: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Creating RawArray with float64 data, n_channels=19, n_times=19794
#     Range : 0 ... 19793 =      0.000 ...   154.633 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 77 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 77 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=19026
#     Range : 0 ... 19025 =      0.000 ...   148.633 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=16044
#     Range : 0 ... 16043 =      0.000 ...   125.336 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 62 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=14304
#     Range : 0 ... 14303 =      0.000 ...   111.742 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 55 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=16549
#     Range : 0 ... 16548 =      0.000 ...   129.281 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 64 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=15310
#     Range : 0 ... 15309 =      0.000 ...   119.602 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=15943
#     Range : 0 ... 15942 =      0.000 ...   124.547 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 62 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=15574
#     Range : 0 ... 15573 =      0.000 ...   121.664 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=13304
#     Range : 0 ... 13303 =      0.000 ...   103.930 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Not setting metadata
# 51 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 51 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=15651
#     Range : 0 ... 15650 =      0.000 ...   122.266 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 61 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 61 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=19301
#     Range : 0 ... 19300 =      0.000 ...   150.781 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=25659
#     Range : 0 ... 25658 =      0.000 ...   200.453 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 100 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=12007
#     Range : 0 ... 12006 =      0.000 ...    93.797 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 46 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 46 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=12033
#     Range : 0 ... 12032 =      0.000 ...    94.000 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 47 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 47 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=16377
#     Range : 0 ... 16376 =      0.000 ...   127.938 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 63 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 63 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=14550
#     Range : 0 ... 14549 =      0.000 ...   113.664 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 56 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=15378
#     Range : 0 ... 15377 =      0.000 ...   120.133 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=14721
#     Range : 0 ... 14720 =      0.000 ...   115.000 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 57 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 57 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=11208
#     Range : 0 ... 11207 =      0.000 ...    87.555 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 43 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 43 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=17604
#     Range : 0 ... 17603 =      0.000 ...   137.523 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 68 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=16686
#     Range : 0 ... 16685 =      0.000 ...   130.352 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 65 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=15073
#     Range : 0 ... 15072 =      0.000 ...   117.750 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 58 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=13359
#     Range : 0 ... 13358 =      0.000 ...   104.359 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 52 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 52 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=12488
#     Range : 0 ... 12487 =      0.000 ...    97.555 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 48 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=17187
#     Range : 0 ... 17186 =      0.000 ...   134.266 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 67 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 67 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=15607
#     Range : 0 ... 15606 =      0.000 ...   121.922 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=14209
#     Range : 0 ... 14208 =      0.000 ...   111.000 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s finished
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 55 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=17098
#     Range : 0 ... 17097 =      0.000 ...   133.570 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 66 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=17562
#     Range : 0 ... 17561 =      0.000 ...   137.195 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 68 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=20914
#     Range : 0 ... 20913 =      0.000 ...   163.383 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 81 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 81 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=43252
#     Range : 0 ... 43251 =      0.000 ...   337.898 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 168 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 168 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=24241
#     Range : 0 ... 24240 =      0.000 ...   189.375 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 94 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 94 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=16697
#     Range : 0 ... 16696 =      0.000 ...   130.438 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 65 events and 257 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=19, n_times=12673
#     Range : 0 ... 12672 =      0.000 ...    99.000 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# ...
# Epoch 21/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8478 - loss: 0.3533 - val_accuracy: 0.8886 - val_loss: 0.2756 - learning_rate: 0.0010
# Epoch 22/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8556 - loss: 0.3290 - val_accuracy: 0.8839 - val_loss: 0.2727 - learning_rate: 0.0010
# Epoch 23/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8597 - loss: 0.3293 - val_accuracy: 0.9011 - val_loss: 0.2667 - learning_rate: 0.0010
# Epoch 24/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8609 - loss: 0.3218 - val_accuracy: 0.8886 - val_loss: 0.2688 - learning_rate: 0.0010
# Epoch 25/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8561 - loss: 0.3284 - val_accuracy: 0.9053 - val_loss: 0.2547 - learning_rate: 0.0010
# Epoch 26/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8685 - loss: 0.3231 - val_accuracy: 0.9011 - val_loss: 0.2494 - learning_rate: 0.0010
# Epoch 27/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8676 - loss: 0.3173 - val_accuracy: 0.9029 - val_loss: 0.2477 - learning_rate: 0.0010
# Epoch 28/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8684 - loss: 0.3115 - val_accuracy: 0.9017 - val_loss: 0.2493 - learning_rate: 0.0010
# Epoch 29/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8770 - loss: 0.2983 - val_accuracy: 0.8815 - val_loss: 0.2819 - learning_rate: 0.0010
# Epoch 30/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8682 - loss: 0.3086 - val_accuracy: 0.9017 - val_loss: 0.2496 - learning_rate: 0.0010
# Epoch 31/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8719 - loss: 0.3035 - val_accuracy: 0.9077 - val_loss: 0.2480 - learning_rate: 0.0010
# Epoch 32/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8689 - loss: 0.3104 - val_accuracy: 0.9113 - val_loss: 0.2375 - learning_rate: 0.0010
# Epoch 33/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8720 - loss: 0.2999 - val_accuracy: 0.9166 - val_loss: 0.2350 - learning_rate: 0.0010
# Epoch 34/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8811 - loss: 0.2991 - val_accuracy: 0.8940 - val_loss: 0.2653 - learning_rate: 0.0010
# Epoch 35/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8718 - loss: 0.3108 - val_accuracy: 0.9089 - val_loss: 0.2338 - learning_rate: 0.0010
# Epoch 36/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8754 - loss: 0.3018 - val_accuracy: 0.8987 - val_loss: 0.2554 - learning_rate: 0.0010
# Epoch 37/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8872 - loss: 0.2748 - val_accuracy: 0.9124 - val_loss: 0.2354 - learning_rate: 0.0010
# Epoch 38/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8740 - loss: 0.3086 - val_accuracy: 0.9077 - val_loss: 0.2419 - learning_rate: 0.0010
# Epoch 39/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8785 - loss: 0.2937 - val_accuracy: 0.9160 - val_loss: 0.2355 - learning_rate: 0.0010
# Epoch 40/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8762 - loss: 0.2828 - val_accuracy: 0.8839 - val_loss: 0.2684 - learning_rate: 0.0010
# Epoch 41/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8742 - loss: 0.2999 - val_accuracy: 0.9065 - val_loss: 0.2389 - learning_rate: 5.0000e-04
# Epoch 42/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8715 - loss: 0.3083 - val_accuracy: 0.9095 - val_loss: 0.2344 - learning_rate: 5.0000e-04
# Epoch 43/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8828 - loss: 0.2851 - val_accuracy: 0.9101 - val_loss: 0.2279 - learning_rate: 5.0000e-04
# Epoch 44/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8751 - loss: 0.2799 - val_accuracy: 0.9130 - val_loss: 0.2235 - learning_rate: 5.0000e-04
# Epoch 45/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8891 - loss: 0.2659 - val_accuracy: 0.9136 - val_loss: 0.2336 - learning_rate: 5.0000e-04
# Epoch 46/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8828 - loss: 0.2735 - val_accuracy: 0.9202 - val_loss: 0.2218 - learning_rate: 5.0000e-04
# Epoch 47/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8811 - loss: 0.2835 - val_accuracy: 0.9178 - val_loss: 0.2227 - learning_rate: 5.0000e-04
# Epoch 48/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8806 - loss: 0.2834 - val_accuracy: 0.9166 - val_loss: 0.2256 - learning_rate: 5.0000e-04
# Epoch 49/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8866 - loss: 0.2832 - val_accuracy: 0.9148 - val_loss: 0.2272 - learning_rate: 5.0000e-04
# Epoch 50/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8823 - loss: 0.2790 - val_accuracy: 0.9136 - val_loss: 0.2233 - learning_rate: 5.0000e-04
# Epoch 51/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8866 - loss: 0.2700 - val_accuracy: 0.9166 - val_loss: 0.2200 - learning_rate: 5.0000e-04
# Epoch 52/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8810 - loss: 0.2851 - val_accuracy: 0.9160 - val_loss: 0.2267 - learning_rate: 5.0000e-04
# Epoch 53/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8862 - loss: 0.2746 - val_accuracy: 0.9184 - val_loss: 0.2252 - learning_rate: 5.0000e-04
# Epoch 54/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8902 - loss: 0.2653 - val_accuracy: 0.9184 - val_loss: 0.2230 - learning_rate: 5.0000e-04
# Epoch 55/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8875 - loss: 0.2744 - val_accuracy: 0.9095 - val_loss: 0.2392 - learning_rate: 5.0000e-04
# Epoch 56/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8819 - loss: 0.2766 - val_accuracy: 0.9107 - val_loss: 0.2323 - learning_rate: 5.0000e-04
# Epoch 57/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8903 - loss: 0.2704 - val_accuracy: 0.9154 - val_loss: 0.2241 - learning_rate: 2.5000e-04
# Epoch 58/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8859 - loss: 0.2749 - val_accuracy: 0.9178 - val_loss: 0.2184 - learning_rate: 2.5000e-04
# Epoch 59/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8909 - loss: 0.2637 - val_accuracy: 0.9172 - val_loss: 0.2197 - learning_rate: 2.5000e-04
# Epoch 60/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8961 - loss: 0.2644 - val_accuracy: 0.9172 - val_loss: 0.2181 - learning_rate: 2.5000e-04
# Epoch 61/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8957 - loss: 0.2589 - val_accuracy: 0.9130 - val_loss: 0.2229 - learning_rate: 2.5000e-04
# Epoch 62/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8868 - loss: 0.2715 - val_accuracy: 0.9172 - val_loss: 0.2173 - learning_rate: 2.5000e-04
# Epoch 63/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8944 - loss: 0.2642 - val_accuracy: 0.9202 - val_loss: 0.2126 - learning_rate: 2.5000e-04
# Epoch 64/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8874 - loss: 0.2672 - val_accuracy: 0.9172 - val_loss: 0.2198 - learning_rate: 2.5000e-04
# Epoch 65/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8862 - loss: 0.2701 - val_accuracy: 0.9142 - val_loss: 0.2203 - learning_rate: 2.5000e-04
# Epoch 66/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8897 - loss: 0.2649 - val_accuracy: 0.9178 - val_loss: 0.2204 - learning_rate: 2.5000e-04
# Epoch 67/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8796 - loss: 0.2830 - val_accuracy: 0.9154 - val_loss: 0.2251 - learning_rate: 2.5000e-04
# Epoch 68/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8993 - loss: 0.2527 - val_accuracy: 0.9190 - val_loss: 0.2146 - learning_rate: 2.5000e-04
# Epoch 69/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8889 - loss: 0.2617 - val_accuracy: 0.9190 - val_loss: 0.2180 - learning_rate: 1.2500e-04
# Epoch 70/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8860 - loss: 0.2722 - val_accuracy: 0.9196 - val_loss: 0.2161 - learning_rate: 1.2500e-04
# Epoch 71/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8895 - loss: 0.2606 - val_accuracy: 0.9166 - val_loss: 0.2180 - learning_rate: 1.2500e-04
# Epoch 72/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8985 - loss: 0.2454 - val_accuracy: 0.9238 - val_loss: 0.2152 - learning_rate: 1.2500e-04
# Epoch 73/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8943 - loss: 0.2595 - val_accuracy: 0.9214 - val_loss: 0.2149 - learning_rate: 1.2500e-04
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Training DeepConvNet...
# Epoch 1/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5273 - loss: 1.1454 - val_accuracy: 0.5688 - val_loss: 0.7352 - learning_rate: 0.0010
# Epoch 2/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5679 - loss: 0.8483 - val_accuracy: 0.6873 - val_loss: 0.6171 - learning_rate: 0.0010
# Epoch 3/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6973 - loss: 0.6819 - val_accuracy: 0.7052 - val_loss: 0.7221 - learning_rate: 0.0010
# Epoch 4/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7691 - loss: 0.5689 - val_accuracy: 0.7558 - val_loss: 0.5013 - learning_rate: 0.0010
# Epoch 5/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7946 - loss: 0.5196 - val_accuracy: 0.7874 - val_loss: 0.5443 - learning_rate: 0.0010
# Epoch 6/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8313 - loss: 0.4335 - val_accuracy: 0.8154 - val_loss: 0.5394 - learning_rate: 0.0010
# Epoch 7/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8149 - loss: 0.4685 - val_accuracy: 0.8392 - val_loss: 0.4362 - learning_rate: 0.0010
# Epoch 8/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8473 - loss: 0.4046 - val_accuracy: 0.8487 - val_loss: 0.3996 - learning_rate: 0.0010
# Epoch 9/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8614 - loss: 0.3624 - val_accuracy: 0.8076 - val_loss: 0.6048 - learning_rate: 0.0010
# Epoch 10/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8693 - loss: 0.3574 - val_accuracy: 0.8523 - val_loss: 0.4428 - learning_rate: 0.0010
# Epoch 11/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8732 - loss: 0.3420 - val_accuracy: 0.8535 - val_loss: 0.4487 - learning_rate: 0.0010
# Epoch 12/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8691 - loss: 0.3538 - val_accuracy: 0.8809 - val_loss: 0.3426 - learning_rate: 0.0010
# Epoch 13/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8778 - loss: 0.3206 - val_accuracy: 0.8993 - val_loss: 0.2955 - learning_rate: 0.0010
# Epoch 14/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8838 - loss: 0.3267 - val_accuracy: 0.9011 - val_loss: 0.2942 - learning_rate: 0.0010
# Epoch 15/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8930 - loss: 0.3068 - val_accuracy: 0.8142 - val_loss: 0.5404 - learning_rate: 0.0010
# Epoch 16/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8904 - loss: 0.3079 - val_accuracy: 0.8344 - val_loss: 0.5925 - learning_rate: 0.0010
# Epoch 17/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8918 - loss: 0.3044 - val_accuracy: 0.8559 - val_loss: 0.4342 - learning_rate: 0.0010
# Epoch 18/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8975 - loss: 0.2828 - val_accuracy: 0.8803 - val_loss: 0.3236 - learning_rate: 0.0010
# Epoch 19/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9012 - loss: 0.2877 - val_accuracy: 0.8678 - val_loss: 0.3956 - learning_rate: 0.0010
# Epoch 20/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9004 - loss: 0.2710 - val_accuracy: 0.8898 - val_loss: 0.3250 - learning_rate: 5.0000e-04
# Epoch 21/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8985 - loss: 0.2802 - val_accuracy: 0.8987 - val_loss: 0.2880 - learning_rate: 5.0000e-04
# Epoch 22/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9120 - loss: 0.2549 - val_accuracy: 0.9119 - val_loss: 0.2878 - learning_rate: 5.0000e-04
# Epoch 23/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9193 - loss: 0.2356 - val_accuracy: 0.8958 - val_loss: 0.2981 - learning_rate: 5.0000e-04
# Epoch 24/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9132 - loss: 0.2534 - val_accuracy: 0.9172 - val_loss: 0.2571 - learning_rate: 5.0000e-04
# Epoch 25/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9115 - loss: 0.2532 - val_accuracy: 0.9160 - val_loss: 0.2685 - learning_rate: 5.0000e-04
# Epoch 26/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9143 - loss: 0.2491 - val_accuracy: 0.9005 - val_loss: 0.3087 - learning_rate: 5.0000e-04
# Epoch 27/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9132 - loss: 0.2514 - val_accuracy: 0.8809 - val_loss: 0.3526 - learning_rate: 5.0000e-04
# Epoch 28/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9170 - loss: 0.2477 - val_accuracy: 0.8696 - val_loss: 0.3961 - learning_rate: 5.0000e-04
# Epoch 29/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9277 - loss: 0.2236 - val_accuracy: 0.9220 - val_loss: 0.2524 - learning_rate: 5.0000e-04
# Epoch 30/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9194 - loss: 0.2480 - val_accuracy: 0.8588 - val_loss: 0.4048 - learning_rate: 5.0000e-04
# Epoch 31/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9112 - loss: 0.2605 - val_accuracy: 0.9071 - val_loss: 0.2839 - learning_rate: 5.0000e-04
# Epoch 32/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9244 - loss: 0.2191 - val_accuracy: 0.9208 - val_loss: 0.2284 - learning_rate: 5.0000e-04
# Epoch 33/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9164 - loss: 0.2426 - val_accuracy: 0.9184 - val_loss: 0.2677 - learning_rate: 5.0000e-04
# Epoch 34/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9289 - loss: 0.2120 - val_accuracy: 0.9095 - val_loss: 0.2736 - learning_rate: 5.0000e-04
# Epoch 35/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9273 - loss: 0.2232 - val_accuracy: 0.8868 - val_loss: 0.3539 - learning_rate: 5.0000e-04
# Epoch 36/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9270 - loss: 0.2144 - val_accuracy: 0.9154 - val_loss: 0.2803 - learning_rate: 5.0000e-04
# Epoch 37/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9293 - loss: 0.2130 - val_accuracy: 0.8982 - val_loss: 0.3324 - learning_rate: 5.0000e-04
# Epoch 38/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9326 - loss: 0.2176 - val_accuracy: 0.9154 - val_loss: 0.2602 - learning_rate: 2.5000e-04
# Epoch 39/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9273 - loss: 0.2171 - val_accuracy: 0.9041 - val_loss: 0.2873 - learning_rate: 2.5000e-04
# Epoch 40/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9357 - loss: 0.2052 - val_accuracy: 0.8791 - val_loss: 0.3615 - learning_rate: 2.5000e-04
# Epoch 41/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9244 - loss: 0.2215 - val_accuracy: 0.8934 - val_loss: 0.3105 - learning_rate: 2.5000e-04
# Epoch 42/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9278 - loss: 0.2125 - val_accuracy: 0.9160 - val_loss: 0.2705 - learning_rate: 2.5000e-04
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Training Random Forest...
#
# Training SVM...
#
# Training Logistic Regression...
# /media/aaron/Windows/Users/yuhan/OneDrive/Desktop/Aaron/College/Hrishi_Chettan/ADHD/tf/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Final Results:
# EEGNET               Mean ROC-AUC: 0.975 ± 0.003
# DEEPCONVNET          Mean ROC-AUC: 0.989 ± 0.003
# RANDOM_FOREST        Mean ROC-AUC: 0.964 ± 0.007
# SVM                  Mean ROC-AUC: 0.850 ± 0.016
# LOGISTIC_REGRESSION  Mean ROC-AUC: 0.780 ± 0.015
